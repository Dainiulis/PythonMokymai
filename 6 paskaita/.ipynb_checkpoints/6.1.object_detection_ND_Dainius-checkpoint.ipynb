# %%
#Įsikeliame reikalingas bibliotekas
import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets
from sklearn.model_selection import train_test_split

import keras

from pylab import rcParams
rcParams['figure.figsize'] = 10, 10

# %%
import keras
from keras.models import Sequential
from keras.utils import np_utils
from keras.preprocessing.image import ImageDataGenerator
from keras.layers import Dense, Activation, Flatten, Dropout, BatchNormalization
from keras.layers import Conv2D, MaxPooling2D
from keras.datasets import cifar10
from keras import regularizers
from keras.callbacks import LearningRateScheduler
import numpy as np

# %%
#Įsikeliame duomenis

(X_train, y_train), (X_test, y_test) =  keras.datasets.cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 3s 0us/step

# %%
# normalizuojame
X_train = X_train / 255
X_test = X_test / 255

# %%
X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train, test_size=0.1, shuffle= True)

# %%
y_train_one_hot = keras.utils.to_categorical(y_train, 10)
y_valid_one_hot = keras.utils.to_categorical(y_valid, 10)
y_test_one_hot = keras.utils.to_categorical(y_test, 10)

# %%
model = keras.models.Sequential()
model.add(keras.layers.Conv2D(filters=10, kernel_size=(3, 3), input_shape=(32, 32, 3), activation='relu'))
model.add(keras.layers.AveragePooling2D())
model.add(keras.layers.Conv2D(filters=20, kernel_size=(3, 3), activation='relu'))
model.add(keras.layers.AveragePooling2D())
model.add(keras.layers.Flatten())
model.add(keras.layers.Dense(80, activation='relu'))
model.add(keras.layers.Dense(10, activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_38 (Conv2D)           (None, 30, 30, 10)        280
# _________________________________________________________________
# average_pooling2d (AveragePo (None, 15, 15, 10)        0
# _________________________________________________________________
# conv2d_39 (Conv2D)           (None, 13, 13, 20)        1820
# _________________________________________________________________
# average_pooling2d_1 (Average (None, 6, 6, 20)          0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 720)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 80)                57680
# _________________________________________________________________
# dense_4 (Dense)              (None, 10)                810
# =================================================================
# Total params: 60,590
# Trainable params: 60,590
# Non-trainable params: 0
# _________________________________________________________________

# %%
h = model.fit(X_train, y_train_one_hot, validation_data=(X_valid, y_valid_one_hot), epochs=100, batch_size=64)
# Out:
# Epoch 1/100
# 704/704 [==============================] - 11s 16ms/step - loss: 1.6562 - accuracy: 0.3993 - val_loss: 1.4665 - val_accuracy: 0.4700
# Epoch 2/100
# 704/704 [==============================] - 12s 16ms/step - loss: 1.3835 - accuracy: 0.5040 - val_loss: 1.3714 - val_accuracy: 0.5098
# Epoch 3/100
# 704/704 [==============================] - 14s 20ms/step - loss: 1.2944 - accuracy: 0.5416 - val_loss: 1.2746 - val_accuracy: 0.5624
# Epoch 4/100
# 704/704 [==============================] - 15s 21ms/step - loss: 1.2263 - accuracy: 0.5656 - val_loss: 1.2273 - val_accuracy: 0.5732
# Epoch 5/100
# 704/704 [==============================] - 13s 19ms/step - loss: 1.1721 - accuracy: 0.5883 - val_loss: 1.1859 - val_accuracy: 0.5830
# Epoch 6/100
# 704/704 [==============================] - 16s 22ms/step - loss: 1.1223 - accuracy: 0.6063 - val_loss: 1.1710 - val_accuracy: 0.5972
# Epoch 7/100
# 704/704 [==============================] - 13s 18ms/step - loss: 1.0876 - accuracy: 0.6165 - val_loss: 1.1378 - val_accuracy: 0.6034
# Epoch 8/100
# 704/704 [==============================] - 13s 19ms/step - loss: 1.0474 - accuracy: 0.6339 - val_loss: 1.0986 - val_accuracy: 0.6160
# Epoch 9/100
# 704/704 [==============================] - 12s 17ms/step - loss: 1.0126 - accuracy: 0.6452 - val_loss: 1.0778 - val_accuracy: 0.6138
# Epoch 10/100
# 704/704 [==============================] - 13s 18ms/step - loss: 0.9919 - accuracy: 0.6517 - val_loss: 1.0776 - val_accuracy: 0.6232
# Epoch 11/100
# 704/704 [==============================] - 14s 20ms/step - loss: 0.9630 - accuracy: 0.6641 - val_loss: 1.1096 - val_accuracy: 0.6068
# Epoch 12/100
# 704/704 [==============================] - 14s 20ms/step - loss: 0.9414 - accuracy: 0.6714 - val_loss: 1.0476 - val_accuracy: 0.6416
# Epoch 13/100
# 704/704 [==============================] - 13s 18ms/step - loss: 0.9197 - accuracy: 0.6799 - val_loss: 1.0365 - val_accuracy: 0.6442
# Epoch 14/100
# 704/704 [==============================] - 14s 20ms/step - loss: 0.8995 - accuracy: 0.6870 - val_loss: 1.0297 - val_accuracy: 0.6444
# Epoch 15/100
# 704/704 [==============================] - 15s 21ms/step - loss: 0.8830 - accuracy: 0.6904 - val_loss: 1.0661 - val_accuracy: 0.6340
# Epoch 16/100
# 704/704 [==============================] - 13s 19ms/step - loss: 0.8611 - accuracy: 0.7005 - val_loss: 1.0452 - val_accuracy: 0.6380
# Epoch 17/100
# 704/704 [==============================] - 13s 18ms/step - loss: 0.8444 - accuracy: 0.7051 - val_loss: 1.0395 - val_accuracy: 0.6486
# Epoch 18/100
# 704/704 [==============================] - 14s 19ms/step - loss: 0.8324 - accuracy: 0.7084 - val_loss: 1.0640 - val_accuracy: 0.6380
# Epoch 19/100
# 704/704 [==============================] - 13s 19ms/step - loss: 0.8154 - accuracy: 0.7167 - val_loss: 1.0272 - val_accuracy: 0.6506
# Epoch 20/100
# 704/704 [==============================] - 14s 20ms/step - loss: 0.7996 - accuracy: 0.7213 - val_loss: 1.0435 - val_accuracy: 0.6442
# Epoch 21/100
# 704/704 [==============================] - 14s 19ms/step - loss: 0.7866 - accuracy: 0.7266 - val_loss: 1.0483 - val_accuracy: 0.6488
# Epoch 22/100
# 704/704 [==============================] - 14s 19ms/step - loss: 0.7743 - accuracy: 0.7299 - val_loss: 1.0221 - val_accuracy: 0.6522
# Epoch 23/100
# 704/704 [==============================] - 13s 19ms/step - loss: 0.7618 - accuracy: 0.7336 - val_loss: 1.0713 - val_accuracy: 0.6394
# Epoch 24/100
# 704/704 [==============================] - 14s 20ms/step - loss: 0.7493 - accuracy: 0.7402 - val_loss: 1.0721 - val_accuracy: 0.6360
# Epoch 25/100
# 704/704 [==============================] - 15s 21ms/step - loss: 0.7352 - accuracy: 0.7430 - val_loss: 1.0723 - val_accuracy: 0.6412
# Epoch 26/100
# 704/704 [==============================] - 14s 20ms/step - loss: 0.7247 - accuracy: 0.7470 - val_loss: 1.0420 - val_accuracy: 0.6574
# Epoch 27/100
# 704/704 [==============================] - 14s 20ms/step - loss: 0.7150 - accuracy: 0.7517 - val_loss: 1.0680 - val_accuracy: 0.6468
# Epoch 28/100
# 704/704 [==============================] - 14s 20ms/step - loss: 0.6967 - accuracy: 0.7560 - val_loss: 1.0767 - val_accuracy: 0.6482
# Epoch 29/100
# 704/704 [==============================] - 14s 20ms/step - loss: 0.6880 - accuracy: 0.7608 - val_loss: 1.0884 - val_accuracy: 0.6492
# Epoch 30/100
# 704/704 [==============================] - 14s 20ms/step - loss: 0.6790 - accuracy: 0.7613 - val_loss: 1.0985 - val_accuracy: 0.6440
# Epoch 31/100
# 704/704 [==============================] - 14s 20ms/step - loss: 0.6659 - accuracy: 0.7678 - val_loss: 1.0834 - val_accuracy: 0.6504
# Epoch 32/100
# 704/704 [==============================] - 15s 21ms/step - loss: 0.6580 - accuracy: 0.7701 - val_loss: 1.0883 - val_accuracy: 0.6506
# Epoch 33/100
# 704/704 [==============================] - 14s 20ms/step - loss: 0.6480 - accuracy: 0.7744 - val_loss: 1.0946 - val_accuracy: 0.6518
# Epoch 34/100
# 704/704 [==============================] - 14s 20ms/step - loss: 0.6406 - accuracy: 0.7745 - val_loss: 1.1253 - val_accuracy: 0.6536
# Epoch 35/100
# 704/704 [==============================] - 14s 20ms/step - loss: 0.6301 - accuracy: 0.7787 - val_loss: 1.1487 - val_accuracy: 0.6422
# Epoch 36/100
# 704/704 [==============================] - 14s 20ms/step - loss: 0.6221 - accuracy: 0.7810 - val_loss: 1.1266 - val_accuracy: 0.6502
# Epoch 37/100
# 704/704 [==============================] - 15s 21ms/step - loss: 0.6109 - accuracy: 0.7864 - val_loss: 1.1499 - val_accuracy: 0.6422
# Epoch 38/100
# 704/704 [==============================] - 17s 24ms/step - loss: 0.6023 - accuracy: 0.7888 - val_loss: 1.1479 - val_accuracy: 0.6480
# Epoch 39/100
# 704/704 [==============================] - 16s 22ms/step - loss: 0.5986 - accuracy: 0.7901 - val_loss: 1.1607 - val_accuracy: 0.6472oss: 0.5993 - accuracy
# Epoch 40/100
# 704/704 [==============================] - 16s 23ms/step - loss: 0.5864 - accuracy: 0.7928 - val_loss: 1.1839 - val_accuracy: 0.6394
# Epoch 41/100
# 704/704 [==============================] - 17s 24ms/step - loss: 0.5764 - accuracy: 0.7963 - val_loss: 1.1622 - val_accuracy: 0.6504
# Epoch 42/100
# 704/704 [==============================] - 15s 21ms/step - loss: 0.5690 - accuracy: 0.8022 - val_loss: 1.2202 - val_accuracy: 0.6412
# Epoch 43/100
# 704/704 [==============================] - 15s 22ms/step - loss: 0.5619 - accuracy: 0.8034 - val_loss: 1.1976 - val_accuracy: 0.6460
# Epoch 44/100
# 704/704 [==============================] - 15s 22ms/step - loss: 0.5528 - accuracy: 0.8068 - val_loss: 1.2535 - val_accuracy: 0.6378
# Epoch 45/100
# 704/704 [==============================] - 16s 22ms/step - loss: 0.5478 - accuracy: 0.8079 - val_loss: 1.2108 - val_accuracy: 0.6402
# Epoch 46/100
# 704/704 [==============================] - 15s 21ms/step - loss: 0.5393 - accuracy: 0.8112 - val_loss: 1.2489 - val_accuracy: 0.6442
# Epoch 47/100
# 704/704 [==============================] - 14s 20ms/step - loss: 0.5329 - accuracy: 0.8106 - val_loss: 1.2751 - val_accuracy: 0.6360
# Epoch 48/100
# 704/704 [==============================] - 14s 19ms/step - loss: 0.5248 - accuracy: 0.8144 - val_loss: 1.2377 - val_accuracy: 0.6402
# Epoch 49/100
# 704/704 [==============================] - 14s 20ms/step - loss: 0.5198 - accuracy: 0.8165 - val_loss: 1.2753 - val_accuracy: 0.6468
# Epoch 50/100
# 704/704 [==============================] - 14s 20ms/step - loss: 0.5110 - accuracy: 0.8193 - val_loss: 1.2891 - val_accuracy: 0.6436
# Epoch 51/100
# 704/704 [==============================] - 13s 19ms/step - loss: 0.5071 - accuracy: 0.8215 - val_loss: 1.2812 - val_accuracy: 0.6412
# Epoch 52/100
# 704/704 [==============================] - 13s 18ms/step - loss: 0.4980 - accuracy: 0.8246 - val_loss: 1.3089 - val_accuracy: 0.6404
# Epoch 53/100
# 704/704 [==============================] - 13s 19ms/step - loss: 0.4910 - accuracy: 0.8257 - val_loss: 1.3260 - val_accuracy: 0.6354
# Epoch 54/100
# 704/704 [==============================] - 15s 21ms/step - loss: 0.4824 - accuracy: 0.8297 - val_loss: 1.3171 - val_accuracy: 0.6376
# Epoch 55/100
# 704/704 [==============================] - 15s 21ms/step - loss: 0.4818 - accuracy: 0.8296 - val_loss: 1.4026 - val_accuracy: 0.6360
# Epoch 56/100
# 704/704 [==============================] - 16s 23ms/step - loss: 0.4736 - accuracy: 0.8316 - val_loss: 1.3634 - val_accuracy: 0.6362
# Epoch 57/100
# 704/704 [==============================] - 17s 24ms/step - loss: 0.4638 - accuracy: 0.8365 - val_loss: 1.3593 - val_accuracy: 0.6356
# Epoch 58/100
# 704/704 [==============================] - 16s 23ms/step - loss: 0.4619 - accuracy: 0.8368 - val_loss: 1.4148 - val_accuracy: 0.6294
# Epoch 59/100
# 704/704 [==============================] - 16s 23ms/step - loss: 0.4581 - accuracy: 0.8379 - val_loss: 1.3871 - val_accuracy: 0.6390
# Epoch 60/100
# 704/704 [==============================] - 16s 23ms/step - loss: 0.4454 - accuracy: 0.8425 - val_loss: 1.4534 - val_accuracy: 0.6296
# Epoch 61/100
# 704/704 [==============================] - 16s 23ms/step - loss: 0.4429 - accuracy: 0.8423 - val_loss: 1.4533 - val_accuracy: 0.6330
# Epoch 62/100
# 704/704 [==============================] - 16s 23ms/step - loss: 0.4382 - accuracy: 0.8453 - val_loss: 1.4342 - val_accuracy: 0.6360
# Epoch 63/100
# 704/704 [==============================] - 16s 23ms/step - loss: 0.4313 - accuracy: 0.8460 - val_loss: 1.4461 - val_accuracy: 0.6330
# Epoch 64/100
# 704/704 [==============================] - 15s 21ms/step - loss: 0.4275 - accuracy: 0.8480 - val_loss: 1.4817 - val_accuracy: 0.6288
# Epoch 65/100
# 704/704 [==============================] - 14s 20ms/step - loss: 0.4205 - accuracy: 0.8493 - val_loss: 1.4658 - val_accuracy: 0.6306
# Epoch 66/100
# 704/704 [==============================] - 14s 21ms/step - loss: 0.4170 - accuracy: 0.8515 - val_loss: 1.5197 - val_accuracy: 0.6308
# Epoch 67/100
# 704/704 [==============================] - 15s 22ms/step - loss: 0.4137 - accuracy: 0.8534 - val_loss: 1.5323 - val_accuracy: 0.6302
# Epoch 68/100
# 704/704 [==============================] - 15s 21ms/step - loss: 0.4039 - accuracy: 0.8572 - val_loss: 1.5453 - val_accuracy: 0.6336
# Epoch 69/100
# 704/704 [==============================] - 16s 23ms/step - loss: 0.4023 - accuracy: 0.8564 - val_loss: 1.5583 - val_accuracy: 0.6316
# Epoch 70/100
# 704/704 [==============================] - 19s 26ms/step - loss: 0.3997 - accuracy: 0.8583 - val_loss: 1.5507 - val_accuracy: 0.6280
# Epoch 71/100
# 704/704 [==============================] - 16s 23ms/step - loss: 0.3885 - accuracy: 0.8610 - val_loss: 1.5847 - val_accuracy: 0.6316
# Epoch 72/100
# 704/704 [==============================] - 16s 23ms/step - loss: 0.3898 - accuracy: 0.8615 - val_loss: 1.6229 - val_accuracy: 0.6276
# Epoch 73/100
# 704/704 [==============================] - 16s 22ms/step - loss: 0.3821 - accuracy: 0.8623 - val_loss: 1.6436 - val_accuracy: 0.6290
# Epoch 74/100
# 704/704 [==============================] - 17s 24ms/step - loss: 0.3766 - accuracy: 0.8659 - val_loss: 1.6636 - val_accuracy: 0.6236
# Epoch 75/100
# 704/704 [==============================] - 15s 22ms/step - loss: 0.3720 - accuracy: 0.8680 - val_loss: 1.6542 - val_accuracy: 0.6236
# Epoch 76/100
# 704/704 [==============================] - 15s 21ms/step - loss: 0.3667 - accuracy: 0.8688 - val_loss: 1.6666 - val_accuracy: 0.6258
# Epoch 77/100
# 704/704 [==============================] - 16s 22ms/step - loss: 0.3624 - accuracy: 0.8717 - val_loss: 1.7065 - val_accuracy: 0.6240
# Epoch 78/100
# 704/704 [==============================] - 15s 22ms/step - loss: 0.3573 - accuracy: 0.8721 - val_loss: 1.7375 - val_accuracy: 0.6258
# Epoch 79/100
# 704/704 [==============================] - 13s 18ms/step - loss: 0.3560 - accuracy: 0.8734 - val_loss: 1.7535 - val_accuracy: 0.6214
# Epoch 80/100
# 704/704 [==============================] - 13s 18ms/step - loss: 0.3494 - accuracy: 0.8737 - val_loss: 1.7460 - val_accuracy: 0.6216
# Epoch 81/100
# 704/704 [==============================] - 13s 19ms/step - loss: 0.3458 - accuracy: 0.8781 - val_loss: 1.8087 - val_accuracy: 0.6190
# Epoch 82/100
# 704/704 [==============================] - 13s 19ms/step - loss: 0.3408 - accuracy: 0.8771 - val_loss: 1.7990 - val_accuracy: 0.6260
# Epoch 83/100
# 704/704 [==============================] - 15s 21ms/step - loss: 0.3387 - accuracy: 0.8784 - val_loss: 1.8357 - val_accuracy: 0.6204
# Epoch 84/100
# 704/704 [==============================] - 15s 21ms/step - loss: 0.3300 - accuracy: 0.8829 - val_loss: 1.8360 - val_accuracy: 0.6248
# Epoch 85/100
# 704/704 [==============================] - 15s 21ms/step - loss: 0.3326 - accuracy: 0.8797 - val_loss: 1.9118 - val_accuracy: 0.6204
# Epoch 86/100
# 704/704 [==============================] - 15s 21ms/step - loss: 0.3255 - accuracy: 0.8811 - val_loss: 1.8653 - val_accuracy: 0.6190
# Epoch 87/100
# 704/704 [==============================] - 15s 21ms/step - loss: 0.3205 - accuracy: 0.8852 - val_loss: 1.9123 - val_accuracy: 0.6180
# Epoch 88/100
# 704/704 [==============================] - 15s 21ms/step - loss: 0.3140 - accuracy: 0.8879 - val_loss: 1.9336 - val_accuracy: 0.6204
# Epoch 89/100
# 704/704 [==============================] - 15s 21ms/step - loss: 0.3173 - accuracy: 0.8876 - val_loss: 1.9954 - val_accuracy: 0.6176
# Epoch 90/100
# 704/704 [==============================] - 16s 22ms/step - loss: 0.3138 - accuracy: 0.8867 - val_loss: 1.9598 - val_accuracy: 0.6182
# Epoch 91/100
# 704/704 [==============================] - 15s 21ms/step - loss: 0.3051 - accuracy: 0.8906 - val_loss: 2.0042 - val_accuracy: 0.6246
# Epoch 92/100
# 704/704 [==============================] - 15s 21ms/step - loss: 0.3042 - accuracy: 0.8911 - val_loss: 2.0418 - val_accuracy: 0.6188
# Epoch 93/100
# 704/704 [==============================] - 15s 21ms/step - loss: 0.3072 - accuracy: 0.8894 - val_loss: 2.0230 - val_accuracy: 0.6166
# Epoch 94/100
# 704/704 [==============================] - 15s 22ms/step - loss: 0.2972 - accuracy: 0.8944 - val_loss: 2.0641 - val_accuracy: 0.6234
# Epoch 95/100
# 704/704 [==============================] - 15s 21ms/step - loss: 0.2906 - accuracy: 0.8973 - val_loss: 2.0562 - val_accuracy: 0.6244
# Epoch 96/100
# 704/704 [==============================] - 15s 22ms/step - loss: 0.2920 - accuracy: 0.8951 - val_loss: 2.1241 - val_accuracy: 0.6180
# Epoch 97/100
# 704/704 [==============================] - 15s 21ms/step - loss: 0.2882 - accuracy: 0.8975 - val_loss: 2.1411 - val_accuracy: 0.6148
# Epoch 98/100
# 704/704 [==============================] - 15s 21ms/step - loss: 0.2805 - accuracy: 0.9008 - val_loss: 2.1325 - val_accuracy: 0.6166
# Epoch 99/100
# 704/704 [==============================] - 16s 22ms/step - loss: 0.2788 - accuracy: 0.8992 - val_loss: 2.1873 - val_accuracy: 0.6182
# Epoch 100/100
# 704/704 [==============================] - 16s 23ms/step - loss: 0.2746 - accuracy: 0.9015 - val_loss: 2.2303 - val_accuracy: 0.6176

# %%
model.evaluate(X_test, y_test_one_hot)

# %%
# nupiesti confusion matrix
# kia architektura

# %% [markdown]
# https://appliedmachinelearning.blog/2018/03/24/achieving-90-accuracy-in-object-recognition-task-on-cifar-10-dataset-with-keras-convolutional-neural-networks/#:~:text=CIFAR%2D10%20is%20an%20established,images%20in%20the%20official%20data.

# %%
def lr_schedule(epoch):
    lrate = 0.001
    if epoch > 75:
        lrate = 0.0005
    if epoch > 100:
        lrate = 0.0003
    return lrate

# %%
weight_decay = 1e-4
model = Sequential()
model.add(Conv2D(32, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay), input_shape=X_train.shape[1:]))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(Conv2D(32, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.2))
 
model.add(Conv2D(64, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(Conv2D(64, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.3))
 
model.add(Conv2D(128, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(Conv2D(128, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.4))
 
model.add(Flatten())
model.add(Dense(10, activation='softmax'))
 
model.summary()
 
#data augmentation
datagen = ImageDataGenerator(
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    )
datagen.fit(X_train)
 
#training
batch_size = 64
 
opt_rms = keras.optimizers.RMSprop(lr=0.001, decay=1e-6)
model.compile(loss='categorical_crossentropy', optimizer=opt_rms, metrics=['accuracy'])
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 32)        896
# _________________________________________________________________
# activation (Activation)      (None, 32, 32, 32)        0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 32, 32, 32)        128
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 32)        9248
# _________________________________________________________________
# activation_1 (Activation)    (None, 32, 32, 32)        0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 32, 32, 32)        128
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 16, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 64)        18496
# _________________________________________________________________
# activation_2 (Activation)    (None, 16, 16, 64)        0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 16, 16, 64)        256
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 16, 16, 64)        36928
# _________________________________________________________________
# activation_3 (Activation)    (None, 16, 16, 64)        0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 16, 16, 64)        256
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 8, 8, 128)         73856
# _________________________________________________________________
# activation_4 (Activation)    (None, 8, 8, 128)         0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 8, 8, 128)         512
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 8, 8, 128)         147584
# _________________________________________________________________
# activation_5 (Activation)    (None, 8, 8, 128)         0
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 8, 8, 128)         512
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 10)                20490
# =================================================================
# Total params: 309,290
# Trainable params: 308,394
# Non-trainable params: 896
# _________________________________________________________________

# %%
model.fit_generator(datagen.flow(X_train, y_train_one_hot, batch_size=batch_size),\
                    steps_per_epoch=X_train.shape[0] // batch_size,epochs=125,\
                    verbose=1,validation_data=(X_test, y_test_one_hot), callbacks=[LearningRateScheduler(lr_schedule)])
# Out:
# WARNING:tensorflow:From <ipython-input-9-ac6d0f028f4b>:1: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 1/125
# 703/703 [==============================] - 22s 31ms/step - loss: 1.9687 - accuracy: 0.4117 - val_loss: 1.6075 - val_accuracy: 0.5199
# Epoch 2/125
# 703/703 [==============================] - 22s 31ms/step - loss: 1.3239 - accuracy: 0.5759 - val_loss: 1.0915 - val_accuracy: 0.6563
# Epoch 3/125
# 703/703 [==============================] - 21s 31ms/step - loss: 1.1180 - accuracy: 0.6426 - val_loss: 1.0996 - val_accuracy: 0.6715
# Epoch 4/125
# 703/703 [==============================] - 22s 31ms/step - loss: 1.0141 - accuracy: 0.6797 - val_loss: 0.9663 - val_accuracy: 0.6999
# Epoch 5/125
# 703/703 [==============================] - 22s 31ms/step - loss: 0.9542 - accuracy: 0.6993 - val_loss: 1.0813 - val_accuracy: 0.6977
# Epoch 6/125
# 703/703 [==============================] - 21s 30ms/step - loss: 0.9053 - accuracy: 0.7231 - val_loss: 1.0585 - val_accuracy: 0.6987
# Epoch 7/125
# 703/703 [==============================] - 22s 31ms/step - loss: 0.8674 - accuracy: 0.7334 - val_loss: 1.0184 - val_accuracy: 0.7053
# Epoch 8/125
# 703/703 [==============================] - 22s 31ms/step - loss: 0.8328 - accuracy: 0.7479 - val_loss: 0.7761 - val_accuracy: 0.7721
# Epoch 9/125
# 703/703 [==============================] - 22s 31ms/step - loss: 0.8111 - accuracy: 0.7574 - val_loss: 0.8074 - val_accuracy: 0.7636
# Epoch 10/125
# 703/703 [==============================] - 21s 30ms/step - loss: 0.7953 - accuracy: 0.7658 - val_loss: 0.7602 - val_accuracy: 0.7848
# Epoch 11/125
# 703/703 [==============================] - 22s 31ms/step - loss: 0.7745 - accuracy: 0.7719 - val_loss: 0.7188 - val_accuracy: 0.7934
# Epoch 12/125
# 703/703 [==============================] - 22s 31ms/step - loss: 0.7614 - accuracy: 0.7796 - val_loss: 0.7818 - val_accuracy: 0.7803
# Epoch 13/125
# 703/703 [==============================] - 22s 31ms/step - loss: 0.7469 - accuracy: 0.7860 - val_loss: 0.8013 - val_accuracy: 0.7773
# Epoch 14/125
# 703/703 [==============================] - 22s 31ms/step - loss: 0.7391 - accuracy: 0.7887 - val_loss: 0.7289 - val_accuracy: 0.7991
# Epoch 15/125
# 703/703 [==============================] - 22s 31ms/step - loss: 0.7243 - accuracy: 0.7941 - val_loss: 0.7052 - val_accuracy: 0.8071
# Epoch 16/125
# 703/703 [==============================] - 22s 31ms/step - loss: 0.7182 - accuracy: 0.7948 - val_loss: 0.7129 - val_accuracy: 0.8066
# Epoch 17/125
# 703/703 [==============================] - 22s 31ms/step - loss: 0.7095 - accuracy: 0.8000 - val_loss: 0.7341 - val_accuracy: 0.8002
# Epoch 18/125
# 703/703 [==============================] - 21s 30ms/step - loss: 0.7012 - accuracy: 0.8034 - val_loss: 0.6592 - val_accuracy: 0.8196
# Epoch 19/125
# 703/703 [==============================] - 22s 31ms/step - loss: 0.6972 - accuracy: 0.8052 - val_loss: 0.7135 - val_accuracy: 0.8114
# Epoch 20/125
# 703/703 [==============================] - 22s 31ms/step - loss: 0.6856 - accuracy: 0.8090 - val_loss: 0.7876 - val_accuracy: 0.7916
# Epoch 21/125
# 703/703 [==============================] - 22s 31ms/step - loss: 0.6817 - accuracy: 0.8111 - val_loss: 0.6985 - val_accuracy: 0.8136
# Epoch 22/125
# 703/703 [==============================] - 21s 31ms/step - loss: 0.6823 - accuracy: 0.8123 - val_loss: 0.6817 - val_accuracy: 0.8202
# Epoch 23/125
# 703/703 [==============================] - 22s 31ms/step - loss: 0.6695 - accuracy: 0.8162 - val_loss: 0.7164 - val_accuracy: 0.8088
# Epoch 24/125
# 703/703 [==============================] - 22s 31ms/step - loss: 0.6670 - accuracy: 0.8159 - val_loss: 0.6667 - val_accuracy: 0.8242
# Epoch 25/125
# 703/703 [==============================] - 21s 30ms/step - loss: 0.6648 - accuracy: 0.8185 - val_loss: 0.6557 - val_accuracy: 0.8313
# Epoch 26/125
# 703/703 [==============================] - 21s 31ms/step - loss: 0.6534 - accuracy: 0.8234 - val_loss: 0.6532 - val_accuracy: 0.8311
# Epoch 27/125
# 703/703 [==============================] - 22s 31ms/step - loss: 0.6592 - accuracy: 0.8237 - val_loss: 0.7619 - val_accuracy: 0.8033
# Epoch 28/125
# 703/703 [==============================] - 21s 30ms/step - loss: 0.6544 - accuracy: 0.8227 - val_loss: 0.6527 - val_accuracy: 0.8287
# Epoch 29/125
# 703/703 [==============================] - 21s 30ms/step - loss: 0.6478 - accuracy: 0.8268 - val_loss: 0.7262 - val_accuracy: 0.7993
# Epoch 30/125
# 703/703 [==============================] - 22s 31ms/step - loss: 0.6456 - accuracy: 0.8263 - val_loss: 0.6019 - val_accuracy: 0.8450
# Epoch 31/125
# 703/703 [==============================] - 22s 31ms/step - loss: 0.6453 - accuracy: 0.8269 - val_loss: 0.6350 - val_accuracy: 0.8307
# Epoch 32/125
# 703/703 [==============================] - 22s 31ms/step - loss: 0.6423 - accuracy: 0.8283 - val_loss: 0.6145 - val_accuracy: 0.8394
# Epoch 33/125
# 703/703 [==============================] - 22s 31ms/step - loss: 0.6400 - accuracy: 0.8262 - val_loss: 0.6316 - val_accuracy: 0.8390
# Epoch 34/125
# 703/703 [==============================] - 22s 31ms/step - loss: 0.6349 - accuracy: 0.8311 - val_loss: 0.6646 - val_accuracy: 0.8295
# Epoch 35/125
# 703/703 [==============================] - 22s 32ms/step - loss: 0.6330 - accuracy: 0.8320 - val_loss: 0.5791 - val_accuracy: 0.8494
# Epoch 36/125
# 703/703 [==============================] - 22s 31ms/step - loss: 0.6246 - accuracy: 0.8364 - val_loss: 0.6489 - val_accuracy: 0.8336
# Epoch 37/125
# 703/703 [==============================] - 22s 31ms/step - loss: 0.6302 - accuracy: 0.8348 - val_loss: 0.6246 - val_accuracy: 0.8416
# Epoch 38/125
# 703/703 [==============================] - 22s 31ms/step - loss: 0.6252 - accuracy: 0.8371 - val_loss: 0.6339 - val_accuracy: 0.8375
# Epoch 39/125
# 703/703 [==============================] - 22s 31ms/step - loss: 0.6270 - accuracy: 0.8335 - val_loss: 0.6912 - val_accuracy: 0.8241
# Epoch 40/125
# 703/703 [==============================] - 22s 31ms/step - loss: 0.6258 - accuracy: 0.8352 - val_loss: 0.7442 - val_accuracy: 0.8160
# Epoch 41/125
# 703/703 [==============================] - 22s 32ms/step - loss: 0.6197 - accuracy: 0.8380 - val_loss: 0.6202 - val_accuracy: 0.8417
# Epoch 42/125
# 703/703 [==============================] - 22s 31ms/step - loss: 0.6210 - accuracy: 0.8381 - val_loss: 0.6380 - val_accuracy: 0.8361
# Epoch 43/125
# 703/703 [==============================] - 22s 31ms/step - loss: 0.6146 - accuracy: 0.8412 - val_loss: 0.7592 - val_accuracy: 0.8065
# Epoch 44/125
# 703/703 [==============================] - 22s 31ms/step - loss: 0.6128 - accuracy: 0.8390 - val_loss: 0.6286 - val_accuracy: 0.8427
# Epoch 45/125
# 703/703 [==============================] - 22s 31ms/step - loss: 0.6149 - accuracy: 0.8404 - val_loss: 0.6480 - val_accuracy: 0.8351
# Epoch 46/125
# 703/703 [==============================] - 23s 33ms/step - loss: 0.6106 - accuracy: 0.8407 - val_loss: 0.6526 - val_accuracy: 0.8368
# Epoch 47/125
# 703/703 [==============================] - 24s 35ms/step - loss: 0.6116 - accuracy: 0.8409 - val_loss: 0.5991 - val_accuracy: 0.8523
# Epoch 48/125
# 703/703 [==============================] - 23s 33ms/step - loss: 0.6094 - accuracy: 0.8435 - val_loss: 0.5978 - val_accuracy: 0.8537
# Epoch 49/125
# 703/703 [==============================] - 23s 33ms/step - loss: 0.6062 - accuracy: 0.8437 - val_loss: 0.6379 - val_accuracy: 0.8355
# Epoch 50/125
# 703/703 [==============================] - 22s 32ms/step - loss: 0.6081 - accuracy: 0.8419 - val_loss: 0.6802 - val_accuracy: 0.8230
# Epoch 51/125
# 703/703 [==============================] - 22s 32ms/step - loss: 0.6085 - accuracy: 0.8428 - val_loss: 0.6431 - val_accuracy: 0.8399
# Epoch 52/125
# 703/703 [==============================] - 22s 32ms/step - loss: 0.6073 - accuracy: 0.8420 - val_loss: 0.6122 - val_accuracy: 0.8492
# Epoch 53/125
# 703/703 [==============================] - 22s 32ms/step - loss: 0.6034 - accuracy: 0.8444 - val_loss: 0.6066 - val_accuracy: 0.8466
# Epoch 54/125
# 703/703 [==============================] - 22s 32ms/step - loss: 0.6009 - accuracy: 0.8444 - val_loss: 0.6205 - val_accuracy: 0.8437
# Epoch 55/125
# 703/703 [==============================] - 23s 33ms/step - loss: 0.6019 - accuracy: 0.8465 - val_loss: 0.6405 - val_accuracy: 0.8405
# Epoch 56/125
# 703/703 [==============================] - 23s 33ms/step - loss: 0.6022 - accuracy: 0.8452 - val_loss: 0.6710 - val_accuracy: 0.8267
# Epoch 57/125
# 703/703 [==============================] - 23s 33ms/step - loss: 0.5970 - accuracy: 0.8469 - val_loss: 0.6041 - val_accuracy: 0.8480
# Epoch 58/125
# 703/703 [==============================] - 23s 32ms/step - loss: 0.6025 - accuracy: 0.8461 - val_loss: 0.7077 - val_accuracy: 0.8235
# Epoch 59/125
# 703/703 [==============================] - 22s 32ms/step - loss: 0.5989 - accuracy: 0.8484 - val_loss: 0.7605 - val_accuracy: 0.8042
# Epoch 60/125
# 703/703 [==============================] - 23s 32ms/step - loss: 0.5942 - accuracy: 0.8484 - val_loss: 0.5802 - val_accuracy: 0.8551
# Epoch 61/125
# 703/703 [==============================] - 23s 32ms/step - loss: 0.5975 - accuracy: 0.8457 - val_loss: 0.6214 - val_accuracy: 0.8444
# Epoch 62/125
# 703/703 [==============================] - 22s 32ms/step - loss: 0.5916 - accuracy: 0.8492 - val_loss: 0.6120 - val_accuracy: 0.8547
# Epoch 63/125
# 703/703 [==============================] - 22s 32ms/step - loss: 0.5960 - accuracy: 0.8487 - val_loss: 0.6410 - val_accuracy: 0.8359
# Epoch 64/125
# 703/703 [==============================] - 22s 31ms/step - loss: 0.5901 - accuracy: 0.8501 - val_loss: 0.6129 - val_accuracy: 0.8475
# Epoch 65/125
# 703/703 [==============================] - 22s 32ms/step - loss: 0.5922 - accuracy: 0.8502 - val_loss: 0.7881 - val_accuracy: 0.8049
# Epoch 66/125
# 703/703 [==============================] - 22s 32ms/step - loss: 0.5901 - accuracy: 0.8506 - val_loss: 0.6333 - val_accuracy: 0.8371
# Epoch 67/125
# 703/703 [==============================] - 22s 31ms/step - loss: 0.5907 - accuracy: 0.8488 - val_loss: 0.5610 - val_accuracy: 0.8670
# Epoch 68/125
# 703/703 [==============================] - 23s 33ms/step - loss: 0.5919 - accuracy: 0.8494 - val_loss: 0.5964 - val_accuracy: 0.8542
# Epoch 69/125
# 703/703 [==============================] - 24s 34ms/step - loss: 0.5853 - accuracy: 0.8499 - val_loss: 0.6241 - val_accuracy: 0.8425
# Epoch 70/125
# 703/703 [==============================] - 24s 34ms/step - loss: 0.5923 - accuracy: 0.8485 - val_loss: 0.6012 - val_accuracy: 0.8505
# Epoch 71/125
# 703/703 [==============================] - 22s 31ms/step - loss: 0.5895 - accuracy: 0.8507 - val_loss: 0.5977 - val_accuracy: 0.8500
# Epoch 72/125
# 703/703 [==============================] - 21s 30ms/step - loss: 0.5847 - accuracy: 0.8510 - val_loss: 0.6770 - val_accuracy: 0.8289
# Epoch 73/125
# 703/703 [==============================] - 21s 31ms/step - loss: 0.5841 - accuracy: 0.8534 - val_loss: 0.5540 - val_accuracy: 0.8691
# Epoch 74/125
# 703/703 [==============================] - 22s 31ms/step - loss: 0.5867 - accuracy: 0.8512 - val_loss: 0.6531 - val_accuracy: 0.8423
# Epoch 75/125
# 703/703 [==============================] - 22s 31ms/step - loss: 0.5852 - accuracy: 0.8521 - val_loss: 0.6179 - val_accuracy: 0.8463
# Epoch 76/125
# 703/703 [==============================] - 22s 31ms/step - loss: 0.5823 - accuracy: 0.8523 - val_loss: 0.6473 - val_accuracy: 0.8384
# Epoch 77/125
# 703/703 [==============================] - 22s 31ms/step - loss: 0.5362 - accuracy: 0.8688 - val_loss: 0.5977 - val_accuracy: 0.8577
# Epoch 78/125
# 703/703 [==============================] - 22s 31ms/step - loss: 0.5203 - accuracy: 0.8732 - val_loss: 0.6091 - val_accuracy: 0.8481
# Epoch 79/125
# 703/703 [==============================] - 21s 31ms/step - loss: 0.5150 - accuracy: 0.8716 - val_loss: 0.5597 - val_accuracy: 0.8621
# Epoch 80/125
# 703/703 [==============================] - 21s 31ms/step - loss: 0.5095 - accuracy: 0.8728 - val_loss: 0.5578 - val_accuracy: 0.8644
# Epoch 81/125
# 703/703 [==============================] - 22s 31ms/step - loss: 0.5030 - accuracy: 0.8768 - val_loss: 0.5516 - val_accuracy: 0.8670
# Epoch 82/125
# 703/703 [==============================] - 22s 31ms/step - loss: 0.5070 - accuracy: 0.8726 - val_loss: 0.5007 - val_accuracy: 0.8751
# Epoch 83/125
# 703/703 [==============================] - 22s 31ms/step - loss: 0.4977 - accuracy: 0.8768 - val_loss: 0.5146 - val_accuracy: 0.8759
# Epoch 84/125
# 703/703 [==============================] - 22s 31ms/step - loss: 0.4920 - accuracy: 0.8754 - val_loss: 0.4983 - val_accuracy: 0.8793
# Epoch 85/125
# 703/703 [==============================] - 22s 31ms/step - loss: 0.4914 - accuracy: 0.8757 - val_loss: 0.5172 - val_accuracy: 0.8709
# Epoch 86/125
# 703/703 [==============================] - 21s 30ms/step - loss: 0.4876 - accuracy: 0.8766 - val_loss: 0.5067 - val_accuracy: 0.8740
# Epoch 87/125
# 703/703 [==============================] - 21s 30ms/step - loss: 0.4831 - accuracy: 0.8780 - val_loss: 0.5105 - val_accuracy: 0.8738
# Epoch 88/125
# 703/703 [==============================] - 22s 31ms/step - loss: 0.4760 - accuracy: 0.8799 - val_loss: 0.6182 - val_accuracy: 0.8449
# Epoch 89/125
# 703/703 [==============================] - 22s 31ms/step - loss: 0.4815 - accuracy: 0.8770 - val_loss: 0.5167 - val_accuracy: 0.8727
# Epoch 90/125
# 703/703 [==============================] - 21s 31ms/step - loss: 0.4740 - accuracy: 0.8809 - val_loss: 0.5425 - val_accuracy: 0.8688
# Epoch 91/125
# 703/703 [==============================] - 21s 30ms/step - loss: 0.4761 - accuracy: 0.8799 - val_loss: 0.5028 - val_accuracy: 0.8741
# Epoch 92/125
# 703/703 [==============================] - 22s 31ms/step - loss: 0.4731 - accuracy: 0.8803 - val_loss: 0.5218 - val_accuracy: 0.8697
# Epoch 93/125
# 703/703 [==============================] - 22s 31ms/step - loss: 0.4686 - accuracy: 0.8820 - val_loss: 0.5348 - val_accuracy: 0.8651
# Epoch 94/125
# 703/703 [==============================] - 22s 31ms/step - loss: 0.4729 - accuracy: 0.8786 - val_loss: 0.5348 - val_accuracy: 0.8649
# Epoch 95/125
# 703/703 [==============================] - 22s 31ms/step - loss: 0.4746 - accuracy: 0.8797 - val_loss: 0.4727 - val_accuracy: 0.8823
# Epoch 96/125
# 703/703 [==============================] - 22s 31ms/step - loss: 0.4741 - accuracy: 0.8780 - val_loss: 0.4793 - val_accuracy: 0.8803
# Epoch 97/125
# 703/703 [==============================] - 22s 31ms/step - loss: 0.4697 - accuracy: 0.8789 - val_loss: 0.4811 - val_accuracy: 0.8827
# Epoch 98/125
# 703/703 [==============================] - 22s 31ms/step - loss: 0.4658 - accuracy: 0.8798 - val_loss: 0.5434 - val_accuracy: 0.8600
# Epoch 99/125
# 703/703 [==============================] - 22s 31ms/step - loss: 0.4682 - accuracy: 0.8785 - val_loss: 0.4814 - val_accuracy: 0.8845
# Epoch 100/125
# 703/703 [==============================] - 22s 31ms/step - loss: 0.4662 - accuracy: 0.8805 - val_loss: 0.4957 - val_accuracy: 0.8747
# Epoch 101/125
# 703/703 [==============================] - 22s 31ms/step - loss: 0.4601 - accuracy: 0.8820 - val_loss: 0.5240 - val_accuracy: 0.8690
# Epoch 102/125
# 703/703 [==============================] - 22s 31ms/step - loss: 0.4466 - accuracy: 0.8866 - val_loss: 0.4609 - val_accuracy: 0.8881
# Epoch 103/125
# 703/703 [==============================] - 22s 31ms/step - loss: 0.4309 - accuracy: 0.8915 - val_loss: 0.4948 - val_accuracy: 0.8774
# Epoch 104/125
# 703/703 [==============================] - 22s 31ms/step - loss: 0.4310 - accuracy: 0.8912 - val_loss: 0.4847 - val_accuracy: 0.8796
# Epoch 105/125
# 703/703 [==============================] - 22s 31ms/step - loss: 0.4256 - accuracy: 0.8921 - val_loss: 0.4790 - val_accuracy: 0.8785
# Epoch 106/125
# 703/703 [==============================] - 21s 30ms/step - loss: 0.4266 - accuracy: 0.8908 - val_loss: 0.4813 - val_accuracy: 0.8770
# Epoch 107/125
# 703/703 [==============================] - 22s 31ms/step - loss: 0.4257 - accuracy: 0.8926 - val_loss: 0.4783 - val_accuracy: 0.8806
# Epoch 108/125
# 703/703 [==============================] - 22s 31ms/step - loss: 0.4194 - accuracy: 0.8926 - val_loss: 0.4670 - val_accuracy: 0.8856
# Epoch 109/125
# 703/703 [==============================] - 22s 31ms/step - loss: 0.4187 - accuracy: 0.8928 - val_loss: 0.5112 - val_accuracy: 0.8714
# Epoch 110/125
# 703/703 [==============================] - 22s 31ms/step - loss: 0.4168 - accuracy: 0.8947 - val_loss: 0.4805 - val_accuracy: 0.8829
# Epoch 111/125
# 703/703 [==============================] - 22s 31ms/step - loss: 0.4196 - accuracy: 0.8924 - val_loss: 0.4576 - val_accuracy: 0.8858
# Epoch 112/125
# 703/703 [==============================] - 22s 31ms/step - loss: 0.4150 - accuracy: 0.8944 - val_loss: 0.4572 - val_accuracy: 0.8865
# Epoch 113/125
# 703/703 [==============================] - 22s 31ms/step - loss: 0.4159 - accuracy: 0.8931 - val_loss: 0.4651 - val_accuracy: 0.8845
# Epoch 114/125
# 703/703 [==============================] - 22s 31ms/step - loss: 0.4146 - accuracy: 0.8934 - val_loss: 0.4808 - val_accuracy: 0.8827
# Epoch 115/125
# 703/703 [==============================] - 22s 31ms/step - loss: 0.4103 - accuracy: 0.8946 - val_loss: 0.4953 - val_accuracy: 0.8745
# Epoch 116/125
# 703/703 [==============================] - 22s 31ms/step - loss: 0.4081 - accuracy: 0.8952 - val_loss: 0.4345 - val_accuracy: 0.8874
# Epoch 117/125
# 703/703 [==============================] - 22s 31ms/step - loss: 0.4106 - accuracy: 0.8959 - val_loss: 0.4844 - val_accuracy: 0.8789
# Epoch 118/125
# 703/703 [==============================] - 22s 31ms/step - loss: 0.4097 - accuracy: 0.8943 - val_loss: 0.4746 - val_accuracy: 0.8781
# Epoch 119/125
# 703/703 [==============================] - 22s 31ms/step - loss: 0.4081 - accuracy: 0.8940 - val_loss: 0.4907 - val_accuracy: 0.8739
# Epoch 120/125
# 703/703 [==============================] - 22s 31ms/step - loss: 0.4102 - accuracy: 0.8948 - val_loss: 0.4563 - val_accuracy: 0.8858
# Epoch 121/125
# 703/703 [==============================] - 22s 31ms/step - loss: 0.4067 - accuracy: 0.8948 - val_loss: 0.4569 - val_accuracy: 0.8870
# Epoch 122/125
# 703/703 [==============================] - 22s 31ms/step - loss: 0.4033 - accuracy: 0.8953 - val_loss: 0.5009 - val_accuracy: 0.8760
# Epoch 123/125
# 703/703 [==============================] - 22s 31ms/step - loss: 0.4013 - accuracy: 0.8964 - val_loss: 0.4863 - val_accuracy: 0.8797
# Epoch 124/125
# 703/703 [==============================] - 22s 31ms/step - loss: 0.4039 - accuracy: 0.8952 - val_loss: 0.4407 - val_accuracy: 0.8902
# Epoch 125/125
# 703/703 [==============================] - 22s 31ms/step - loss: 0.4016 - accuracy: 0.8971 - val_loss: 0.4565 - val_accuracy: 0.8854

# %%
model.save('90perc_300kpar_model.model')
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/tracking/tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/tracking/tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# INFO:tensorflow:Assets written to: 90perc_300kpar_model.model/assets

# %%
# atvaizduojame grafiskai
plt.subplot(1, 2, 1)
plt.title('LOSS')
plt.plot(h.history['loss'], color='red')
plt.plot(h.history['val_loss'], color='green')
plt.subplot(1, 2, 2)
plt.title('Accuracy')
plt.plot(h.history['accuracy'], color='red')
plt.plot(h.history['val_accuracy'], color='green')

# %%
predictions = model.predict(X_test)

# %%
labels = ['airplane', 
          'automobile',
          'bird',
          'cat',
          'deer',
          'dog',
          'frog',
          'horse',
          'ship',
          'truck'
          ]

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sn
import pandas as pd
# suskaiciuojeme cf matrix
cf_matrix = confusion_matrix(y_test_one_hot.argmax(axis=1), predictions.argmax(axis=1))
# konvertuojame i dataframe
df_cm = pd.DataFrame(cf_matrix, index=labels, columns=labels)
print(df_cm)
# plot'inam
plt.figure(figsize = (15,15))
sn.heatmap(df_cm, annot=True, fmt='g')
plt.xlabel('predicted')
plt.ylabel('true value')
plt.show()
# Out:
#             airplane  automobile  bird  cat  ...  frog  horse  ship  truck
# airplane         885           9    18    4  ...     8      9    35     21
# automobile         3         943     1    0  ...     2      1     5     45
# bird              30           1   855   16  ...    41      7     3      6
# cat               16           7    37  715  ...    73     24    16     18
# deer               2           1    22   10  ...    44     16     2      1
# dog                3           3    34   87  ...    51     31     4      9
# frog               4           0     7    4  ...   980      0     1      1
# horse              6           1    12    2  ...    16    921     2      6
# ship              19           3     4    0  ...     3      0   958     13
# truck              6          23     2    2  ...     2      1    11    953
#
# [10 rows x 10 columns]

# %% [markdown]
# # simple net
# 5 mln parametru, uzmigo google collab.
# paimtas is mokslinio straipsnio
# https://arxiv.org/abs/1608.06037

# %%
import keras
import numpy as np
import keras.backend as K
from keras.utils import np_utils
from keras.datasets import cifar10
from keras.models import Sequential
from keras.models import load_model
from keras import regularizers, optimizers
from keras.layers import Conv2D, MaxPooling2D
from keras.preprocessing.image import ImageDataGenerator
from keras.initializers import glorot_normal, RandomNormal, Zeros
from keras.layers import Dense, Activation, Flatten, Dropout, BatchNormalization

# %%
# Data augmentation
datagen = ImageDataGenerator(
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True
    )
datagen.fit(X_train)

# %%
# create model
num_classes = 10
s = 2
weight_decay = 1e-2
act="relu"
model = Sequential()

# Block 1
model.add(Conv2D(64, (3,3), padding='same', kernel_initializer=glorot_normal(), input_shape=X_train.shape[1:]))
model.add(BatchNormalization())
model.add(Activation(act))
model.add(Dropout(0.2))

# Block 2
model.add(Conv2D(128, (3,3), padding='same', kernel_initializer=glorot_normal()))
model.add(BatchNormalization())
model.add(Activation(act))
model.add(Dropout(0.2))

# Block 3
model.add(Conv2D(128, (3,3), padding='same', kernel_initializer=RandomNormal(stddev=0.01)))
model.add(BatchNormalization())
model.add(Activation(act))
model.add(Dropout(0.2))

# Block 4
model.add(Conv2D(128, (3,3), padding='same', kernel_initializer=RandomNormal(stddev=0.01)))
model.add(BatchNormalization())
model.add(Activation(act))
# First Maxpooling
model.add(MaxPooling2D(pool_size=(2,2), strides=s))
model.add(Dropout(0.2))


# Block 5
model.add(Conv2D(128, (3,3), padding='same', kernel_initializer=RandomNormal(stddev=0.01)))
model.add(BatchNormalization())
model.add(Activation(act))
model.add(Dropout(0.2))

# Block 6
model.add(Conv2D(128, (3,3), padding='same', kernel_initializer=glorot_normal()))
model.add(BatchNormalization())
model.add(Activation(act))
model.add(Dropout(0.2))

# Block 7
model.add(Conv2D(256, (3,3), padding='same', kernel_initializer=glorot_normal()))
# Second Maxpooling
model.add(MaxPooling2D(pool_size=(2,2), strides=s))
model.add(BatchNormalization())
model.add(Activation(act))
model.add(Dropout(0.2))


# Block 8
model.add(Conv2D(256, (3,3), padding='same', kernel_initializer=glorot_normal()))
model.add(BatchNormalization())
model.add(Activation(act))
model.add(Dropout(0.2))

# Block 9
model.add(Conv2D(256, (3,3), padding='same', kernel_initializer=glorot_normal()))
model.add(BatchNormalization())
model.add(Activation(act))
model.add(Dropout(0.2))
# Third Maxpooling
model.add(MaxPooling2D(pool_size=(2,2), strides=s))


# Block 10
model.add(Conv2D(512, (3,3), padding='same', kernel_initializer=glorot_normal()))
model.add(BatchNormalization())
model.add(Activation(act))
model.add(Dropout(0.2))

# Block 11  
model.add(Conv2D(2048, (1,1), padding='same', kernel_initializer=glorot_normal()))
model.add(Activation(act))
model.add(Dropout(0.2))

# Block 12  
model.add(Conv2D(256, (1,1), padding='same', kernel_initializer=glorot_normal()))
model.add(Activation(act))
# Fourth Maxpooling
model.add(MaxPooling2D(pool_size=(2,2), strides=s))
model.add(Dropout(0.2))


# Block 13
model.add(Conv2D(256, (3,3), padding='same', kernel_initializer=glorot_normal()))
model.add(Activation(act))
# Fifth Maxpooling
model.add(MaxPooling2D(pool_size=(2,2), strides=s))

# Final Classifier
model.add(Flatten())
model.add(Dense(num_classes, activation='softmax'))
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_25 (Conv2D)           (None, 32, 32, 64)        1792
# _________________________________________________________________
# batch_normalization_22 (Batc (None, 32, 32, 64)        256
# _________________________________________________________________
# activation_25 (Activation)   (None, 32, 32, 64)        0
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 32, 32, 64)        0
# _________________________________________________________________
# conv2d_26 (Conv2D)           (None, 32, 32, 128)       73856
# _________________________________________________________________
# batch_normalization_23 (Batc (None, 32, 32, 128)       512
# _________________________________________________________________
# activation_26 (Activation)   (None, 32, 32, 128)       0
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 32, 32, 128)       0
# _________________________________________________________________
# conv2d_27 (Conv2D)           (None, 32, 32, 128)       147584
# _________________________________________________________________
# batch_normalization_24 (Batc (None, 32, 32, 128)       512
# _________________________________________________________________
# activation_27 (Activation)   (None, 32, 32, 128)       0
# _________________________________________________________________
# dropout_20 (Dropout)         (None, 32, 32, 128)       0
# _________________________________________________________________
# conv2d_28 (Conv2D)           (None, 32, 32, 128)       147584
# _________________________________________________________________
# batch_normalization_25 (Batc (None, 32, 32, 128)       512
# _________________________________________________________________
# activation_28 (Activation)   (None, 32, 32, 128)       0
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 16, 16, 128)       0
# _________________________________________________________________
# dropout_21 (Dropout)         (None, 16, 16, 128)       0
# _________________________________________________________________
# conv2d_29 (Conv2D)           (None, 16, 16, 128)       147584
# _________________________________________________________________
# batch_normalization_26 (Batc (None, 16, 16, 128)       512
# _________________________________________________________________
# activation_29 (Activation)   (None, 16, 16, 128)       0
# _________________________________________________________________
# dropout_22 (Dropout)         (None, 16, 16, 128)       0
# _________________________________________________________________
# conv2d_30 (Conv2D)           (None, 16, 16, 128)       147584
# _________________________________________________________________
# batch_normalization_27 (Batc (None, 16, 16, 128)       512
# _________________________________________________________________
# activation_30 (Activation)   (None, 16, 16, 128)       0
# _________________________________________________________________
# dropout_23 (Dropout)         (None, 16, 16, 128)       0
# _________________________________________________________________
# conv2d_31 (Conv2D)           (None, 16, 16, 256)       295168
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 8, 8, 256)         0
# _________________________________________________________________
# batch_normalization_28 (Batc (None, 8, 8, 256)         1024
# _________________________________________________________________
# activation_31 (Activation)   (None, 8, 8, 256)         0
# _________________________________________________________________
# dropout_24 (Dropout)         (None, 8, 8, 256)         0
# _________________________________________________________________
# conv2d_32 (Conv2D)           (None, 8, 8, 256)         590080
# _________________________________________________________________
# batch_normalization_29 (Batc (None, 8, 8, 256)         1024
# _________________________________________________________________
# activation_32 (Activation)   (None, 8, 8, 256)         0
# _________________________________________________________________
# dropout_25 (Dropout)         (None, 8, 8, 256)         0
# _________________________________________________________________
# conv2d_33 (Conv2D)           (None, 8, 8, 256)         590080
# _________________________________________________________________
# batch_normalization_30 (Batc (None, 8, 8, 256)         1024
# _________________________________________________________________
# activation_33 (Activation)   (None, 8, 8, 256)         0
# _________________________________________________________________
# dropout_26 (Dropout)         (None, 8, 8, 256)         0
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 4, 4, 256)         0
# _________________________________________________________________
# conv2d_34 (Conv2D)           (None, 4, 4, 512)         1180160
# _________________________________________________________________
# batch_normalization_31 (Batc (None, 4, 4, 512)         2048
# _________________________________________________________________
# activation_34 (Activation)   (None, 4, 4, 512)         0
# _________________________________________________________________
# dropout_27 (Dropout)         (None, 4, 4, 512)         0
# _________________________________________________________________
# conv2d_35 (Conv2D)           (None, 4, 4, 2048)        1050624
# _________________________________________________________________
# activation_35 (Activation)   (None, 4, 4, 2048)        0
# _________________________________________________________________
# dropout_28 (Dropout)         (None, 4, 4, 2048)        0
# _________________________________________________________________
# conv2d_36 (Conv2D)           (None, 4, 4, 256)         524544
# _________________________________________________________________
# activation_36 (Activation)   (None, 4, 4, 256)         0
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 2, 2, 256)         0
# _________________________________________________________________
# dropout_29 (Dropout)         (None, 2, 2, 256)         0
# _________________________________________________________________
# conv2d_37 (Conv2D)           (None, 2, 2, 256)         590080
# _________________________________________________________________
# activation_37 (Activation)   (None, 2, 2, 256)         0
# _________________________________________________________________
# max_pooling2d_15 (MaxPooling (None, 1, 1, 256)         0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                2570
# =================================================================
# Total params: 5,497,226
# Trainable params: 5,493,258
# Non-trainable params: 3,968
# _________________________________________________________________

# %%
opt_adm = keras.optimizers.Adadelta()
model.compile(loss='categorical_crossentropy', optimizer=opt_adm, metrics=['accuracy'])

# %%
batch_size = 128
epochs = 25
model.fit_generator(datagen.flow(X_train, y_train_one_hot, batch_size=batch_size),
                    steps_per_epoch=X_train.shape[0] // batch_size, epochs=epochs, 
                    verbose=1, validation_data=(X_test, y_test_one_hot))
# Out:
# Epoch 1/25
#   4/351 [..............................] - ETA: 29:03 - loss: 2.6376 - accuracy: 0.1133
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-29fed2cd4a8a> in <module>
#       1 batch_size = 128
#       2 epochs = 25
# ----> 3 model.fit_generator(datagen.flow(X_train, y_train_one_hot, batch_size=batch_size),
#       4                     steps_per_epoch=X_train.shape[0] // batch_size, epochs=epochs,
#       5                     verbose=1, validation_data=(X_test, y_test_one_hot))
#
# ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\util\deprecation.py in new_func(*args, **kwargs)
#     322               'in a future version' if date is None else ('after %s' % date),
#     323               instructions)
# --> 324       return func(*args, **kwargs)
#     325     return tf_decorator.make_decorator(
#     326         func, new_func, 'deprecated',
#
# ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\keras\engine\training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1463     """
#    1464     _keras_api_gauge.get_cell('fit_generator').set(True)
# -> 1465     return self.fit(
#    1466         generator,
#    1467         steps_per_epoch=steps_per_epoch,
#
# ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\keras\engine\training.py in _method_wrapper(self, *args, **kwargs)
#      64   def _method_wrapper(self, *args, **kwargs):
#      65     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# ---> 66       return method(self, *args, **kwargs)
#      67
#      68     # Running inside `run_distribute_coordinator` already.
#
# ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#     846                 batch_size=batch_size):
#     847               callbacks.on_train_batch_begin(step)
# --> 848               tmp_logs = train_function(iterator)
#     849               # Catch OutOfRangeError for Datasets of unknown size.
#     850               # This blocks until the batch has finished executing.
#
# ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\eager\def_function.py in __call__(self, *args, **kwds)
#     578         xla_context.Exit()
#     579     else:
# --> 580       result = self._call(*args, **kwds)
#     581
#     582     if tracing_count == self._get_tracing_count():
#
# ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\eager\def_function.py in _call(self, *args, **kwds)
#     609       # In this case we have created variables on the first call, so we run the
#     610       # defunned version which is guaranteed to never create variables.
# --> 611       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     612     elif self._stateful_fn is not None:
#     613       # Release the lock early so that multiple threads can perform the call
#
# ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\eager\function.py in __call__(self, *args, **kwargs)
#    2418     with self._lock:
#    2419       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 2420     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2421
#    2422   @property
#
# ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\eager\function.py in _filtered_call(self, args, kwargs)
#    1659       `args` and `kwargs`.
#    1660     """
# -> 1661     return self._call_flat(
#    1662         (t for t in nest.flatten((args, kwargs), expand_composites=True)
#    1663          if isinstance(t, (ops.Tensor,
#
# ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1743         and executing_eagerly):
#    1744       # No tape is watching; skip to running the function.
# -> 1745       return self._build_call_outputs(self._inference_function.call(
#    1746           ctx, args, cancellation_manager=cancellation_manager))
#    1747     forward_backward = self._select_forward_and_backward_functions(
#
# ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     591       with _InterpolateFunctionError(self):
#     592         if cancellation_manager is None:
# --> 593           outputs = execute.execute(
#     594               str(self.signature.name),
#     595               num_outputs=self._num_outputs,
#
# ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      57   try:
#      58     ctx.ensure_initialized()
# ---> 59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:
